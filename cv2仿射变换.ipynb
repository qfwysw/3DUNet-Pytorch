# %% [markdown]
# <a href="https://colab.research.google.com/github/qfwysw/3DUNet-Pytorch/blob/master/cv2%E4%BB%BF%E5%B0%84%E5%8F%98%E6%8D%A2.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %% [markdown]
# # 新段落

# %%
# %cd drive/MyDrive/homework1/image
# Out:
# /content/drive/MyDrive/homework1/image

# %%
import cv2
import numpy as np
import matplotlib.pyplot as plt

img_path = 'dog.jpeg'
image = cv2.imread(img_path)
image = cv2.resize(image,None,fx=0.5,fy=0.5)
mapping = np.array([[1, 0, 0],[0, 1, 0]]).astype(np.float)
# mapping = np.array([x_scale, 0, x_shift],                     # x_shift<0,->left;
#                     [0, y_scale, y_shift]]).astype(np.float)  # y_shift<0,->up;
 
padding =  [ 66.31880208, 111.23558449, 105.38220486]
# mapping 大小2x3, 变换矩阵，一般反映平移或旋转的关系；（w,h）输出大小；boardValue 补值；
crop = cv2.warpAffine(image, mapping, (image.shape[1], image.shape[0]), borderMode=cv2.BORDER_CONSTANT,  borderValue=padding)
plt.imshow(crop)

# %%
import cv2
import numpy as np
import matplotlib.pyplot as plt

img_path = 'dog.jpeg'
image = cv2.imread(img_path)
image = cv2.resize(image,None,fx=0.5,fy=0.5)
# mapping = np.array([[1, 0, 0],[0, 1, 0]]).astype(np.float)
mapping = np.array([[1, 0, -400],[0, 1, -300]]).astype(np.float)  # y_shift<0,->up;
 
padding =  [ 66.31880208, 111.23558449, 105.38220486]
# mapping 大小2x3, 变换矩阵，一般反映平移或旋转的关系；（w,h）输出大小；boardValue 补值；
crop = cv2.warpAffine(image, mapping, (image.shape[1], image.shape[0]), borderMode=cv2.BORDER_CONSTANT,  borderValue=padding)
plt.imshow(crop)

# %%
import cv2
import numpy as np
import matplotlib.pyplot as plt

img_path = 'dog.jpeg'
image = cv2.imread(img_path)
image = cv2.resize(image,None,fx=0.5,fy=0.5)
# mapping = np.array([[1, 0, 0],[0, 1, 0]]).astype(np.float)
mapping = np.array([[1, 0, -400],[0, 1, -300]]).astype(np.float)  # y_shift<0,->up;
 
padding =  [ 66.31880208, 111.23558449, 105.38220486]
# mapping 大小2x3, 变换矩阵，一般反映平移或旋转的关系；（w,h）输出大小；boardValue 补值；
crop = cv2.warpAffine(image, mapping, (1000, 900), borderMode=cv2.BORDER_CONSTANT,  borderValue=padding)
plt.imshow(crop)

# %% [markdown]
# 对图片先进行放缩

# %%
import cv2
import numpy as np
import matplotlib.pyplot as plt

img_path = 'dog.jpeg'
image = cv2.imread(img_path)
image = cv2.resize(image,None,fx=0.5,fy=0.5)
mapping1 = np.array([[1, 0, 0],[0, 1, 0]]).astype(np.float)
mapping2 = np.array([[1.4, 0, 0],[0, 1.4, 0]]).astype(np.float)
mapping3 = np.array([[1, 0, -400],[0, 1, -300]]).astype(np.float)
mapping4 = np.array([[1.4, 0, -400],[0, 1.4, -300]]).astype(np.float)
padding =  [ 66.31880208, 111.23558449, 105.38220486]
# mapping 大小2x3, 变换矩阵，一般反映平移或旋转的关系；（w,h）输出大小；boardValue 补值；
crop1 = cv2.warpAffine(image, mapping1, (image.shape[1], image.shape[0]), borderMode=cv2.BORDER_CONSTANT,  borderValue=padding)
crop2 = cv2.warpAffine(image, mapping2, (image.shape[1], image.shape[0]), borderMode=cv2.BORDER_CONSTANT,  borderValue=padding)
crop3 = cv2.warpAffine(image, mapping3, (image.shape[1], image.shape[0]), borderMode=cv2.BORDER_CONSTANT,  borderValue=padding)
crop4 = cv2.warpAffine(image, mapping4, (image.shape[1], image.shape[0]), borderMode=cv2.BORDER_CONSTANT,  borderValue=padding)
plt.figure()
plt.subplot(1,2,1)
plt.imshow(crop1)
plt.subplot(1,2,2)
plt.imshow(crop2)
# plt.subplot(1,4,3)
# plt.imshow(crop3)
# plt.subplot(1,4,4)
# plt.imshow(crop4)

# %%
import cv2
import numpy as np
import matplotlib.pyplot as plt

img_path = 'dog.jpeg'
image = cv2.imread(img_path)
image = cv2.resize(image,None,fx=0.5,fy=0.5)
mapping1 = np.array([[1, 0, 0],[0, 1, 0]]).astype(np.float)
mapping2 = np.array([[1.4, 0, 0],[0, 1.4, 0]]).astype(np.float)
mapping3 = np.array([[1, 0, -400],[0, 1, -300]]).astype(np.float)
mapping4 = np.array([[1.4, 0, -400],[0, 1.4, -300]]).astype(np.float)
padding =  [ 66.31880208, 111.23558449, 105.38220486]
# mapping 大小2x3, 变换矩阵，一般反映平移或旋转的关系；（w,h）输出大小；boardValue 补值；
crop1 = cv2.warpAffine(image, mapping1, (image.shape[1], image.shape[0]), borderMode=cv2.BORDER_CONSTANT,  borderValue=padding)
crop2 = cv2.warpAffine(image, mapping2, (image.shape[1], image.shape[0]), borderMode=cv2.BORDER_CONSTANT,  borderValue=padding)
crop3 = cv2.warpAffine(image, mapping3, (image.shape[1], image.shape[0]), borderMode=cv2.BORDER_CONSTANT,  borderValue=padding)
crop4 = cv2.warpAffine(image, mapping4, (image.shape[1], image.shape[0]), borderMode=cv2.BORDER_CONSTANT,  borderValue=padding)
plt.figure()
# plt.subplot(1,2,1)
# plt.imshow(crop1)
# plt.subplot(1,2,2)
# plt.imshow(crop2)
plt.subplot(1,2,1)
plt.imshow(crop3)
plt.subplot(1,2,2)
plt.imshow(crop4)

# %%
import cv2
import numpy as np
import matplotlib.pyplot as plt

img_path = 'dog.jpeg'
image = cv2.imread(img_path)
image = cv2.resize(image,None,fx=0.5,fy=0.5)
mapping1 = np.array([[1, 0, 0],[0, 1, 0]]).astype(np.float)
mapping2 = np.array([[1.4, 0, 0],[0, 1.4, 0]]).astype(np.float)
mapping3 = np.array([[1, 0, -400],[0, 1, -300]]).astype(np.float)
mapping4 = np.array([[1.4, 0, -400],[0, 1.4, -300]]).astype(np.float)
padding =  [ 66.31880208, 111.23558449, 105.38220486]
# mapping 大小2x3, 变换矩阵，一般反映平移或旋转的关系；（w,h）输出大小；boardValue 补值；
# crop1 = cv2.warpAffine(image, mapping1, (image.shape[1], image.shape[0]), borderMode=cv2.BORDER_CONSTANT,  borderValue=padding)
# crop2 = cv2.warpAffine(image, mapping2, (image.shape[1], image.shape[0]), borderMode=cv2.BORDER_CONSTANT,  borderValue=padding)
crop3 = cv2.warpAffine(image, mapping3, (1000, 1000), borderMode=cv2.BORDER_CONSTANT,  borderValue=padding)
crop4 = cv2.warpAffine(image, mapping4, (1000, 1000), borderMode=cv2.BORDER_CONSTANT,  borderValue=padding)
plt.figure()
# plt.subplot(1,2,1)
# plt.imshow(crop1)
# plt.subplot(1,2,2)
# plt.imshow(crop2)
plt.subplot(1,2,1)
plt.imshow(crop3)
plt.subplot(1,2,2)
plt.imshow(crop4)
